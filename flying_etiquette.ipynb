# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/flying-etiquette-survey/flying-etiquette.csv")

# %% [markdown]
# Question 1: Percent breakdown of survey participants by age range.

# %%
age_percentage = (df.groupby("Age").count() / len(df))
percentages = []
for x in range(0, len(age_percentage)):
    percentages.append(age_percentage["RespondentID"][x])

palette_color = sns.color_palette('bright')
age_choices = ["18-29", "30-44", "45-60", "61+"]

plt.pie(x=percentages, labels=age_choices, colors=palette_color, autopct='%.2f%%')
plt.title("Percent of Participants by Age Group")
plt.show()
# Out:
# /tmp/ipykernel_863/1232183834.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   percentages.append(age_percentage["RespondentID"][x])

# %%
question = "Is it rude to ask someone to switch seats with you in order to be closer to friends?"
plt.figure(figsize = (8,4))
sns.countplot(x=df[question])
plt.xlabel("")
plt.title("Is it rude to ask someone to switch seats with you in order to be closer to friends?")
# Out:
# /home/WSL_Bootcamp/GrandCircusLabs/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/WSL_Bootcamp/GrandCircusLabs/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/WSL_Bootcamp/GrandCircusLabs/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Is it rude to ask someone to switch seats with you in order to be closer to friends?')

# %% [markdown]
# Question 3: Use the respondents age as a dimension to see if there are any differences to responses to “it [was] rude to ask someone to switch seats with you in order to be closer to friends?”?

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x=question, hue='Age')

plt.xlabel("")
plt.ylabel("Count")
plt.title(f"Responses to '{question}' by Age Group")
plt.legend(title="Age Group")
# Out:
# /home/WSL_Bootcamp/GrandCircusLabs/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/WSL_Bootcamp/GrandCircusLabs/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/WSL_Bootcamp/GrandCircusLabs/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
